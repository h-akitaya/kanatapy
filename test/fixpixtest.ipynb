# %% [markdown]
# # fixpix test

# %% [markdown]
# 2023-04-07 H. Akitaya

# %%
import astropy

# %%
import matplotlib.pyplot as plt

# %%
from astropy.io import fits

# %%
with fits.open('HN0166998ira00_bt.fits') as hdul:
    plt.imshow(hdul[0].data)
